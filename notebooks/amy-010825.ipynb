# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from importlib import reload
from time import time 

import numpy as np
import scipy as sc
import pandas as pd
import torch

import gb1
import models
from utils import str2onehot, process_gb1_selection_experiments

import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rcParams["font.size"] = 12

import seaborn as sns
sns.set_style('whitegrid')

# %% [markdown]
# # load ground-truth landscape

# %%
# binding affinity values (y_n) for all 20^4 = 160k variants (seq_n) of 4 sites of the GB1 protein
df = pd.read_csv('../data/gb1-with-variance.csv')
seq_n = list(df['Variants'].str.lower())
y_n = df['log_fitness'].to_numpy()
var_n = df['estimated_variance'].to_numpy()

# seq2yvar maps every possible length-4 amino acid sequence to a list of two floats,
# the sequence's enrichment score and the estimated variance of the enrichment score
# (the latter was used for training the model, but isn't used after we've trained the model, can ignore)
seq2yvar = {seq: [y, var] for seq, y, var in zip(seq_n, y_n, var_n)}

# one-hot-encodings of all 20^4 sequences
ohe_nxlxa = np.stack([str2onehot(seq, gb1.AA) for seq in seq_n])
print(len(seq_n), y_n.size, ohe_nxlxa.shape)

plt.figure(figsize=(5, 2))
plt.hist(y_n, bins=20, log=True);
plt.xlabel('enrichment score');
plt.ylabel('sequence count');
plt.title('GB1 data');
# Out:
# 160000 160000 (160000, 4, 21)

# %% [markdown]
# # load model and design distributions

# %% [markdown]
# Run this cell

# %%
reload(gb1)
reload(models)

n_hidden = 10
n_model = 3
device = torch.device(0)

model = models.EnrichmentFeedForward(
    4,
    gb1.AA,
    n_hidden=n_hidden,
    n_model=n_model,
    device=device
)
model.load('gb1-h10-5k-030123')

# load all design distributions.
# temp2theta is a dictionary that maps real-valued temperature to the corresponding
# design distribution, which is parameterized by a (seq_len X 4) matrix called theta_lxa.
# each row of theta_lxa gives the logits of a categorical distribution over the 4 nucleotides
# at a site. there are a total of seq_len nucleotide sites, where
# seq_len = (# protein residues) * 3 because there are 3 nucleotides per codon,
# and (# protein residues) = 4 for this dataset.
temperatures = np.arange(0.2, 0.701, 0.005)
temp2theta = {
    round(temp, 4): np.load('/data/wongfanc/gb1-models/gb1-h10-5k-t{:.4f}-030123.npz'.format(temp))['theta_lxa']
    for temp in temperatures
}

# true mean labels of design distributions
temp2mean = gb1.get_true_mean_label_from_theta(temp2theta) 

# sanity-check: plot model predictions on all data
pred_n = model.predict(seq_n)
plt.figure(figsize=(5, 4))
plt.scatter(pred_n, y_n, alpha=0.3, s=1)
plt.plot([-8, 2.5], [-8, 2.5], '--k')
r, p = sc.stats.pearsonr(y_n, pred_n)
rmse = np.sqrt(np.mean(np.square(y_n - pred_n)))

plt.ylim([-8, 2.5]);
plt.xlim([-8, 2.5])
plt.title('Pearson {:.2f}, RMSE {:.2f}'.format(r, rmse));
plt.ylabel('true log enrichment'); plt.xlabel('predicted');

# %% [markdown]
# # sample sequences from a design distribution

# %% [markdown]
# Don't need to run this next cell, just a demo of some functions/variables

# %%
# temperature of interest
# (all possible temperatures defined in 'temperatures' variable in above cell)
temp = 0.4
# desired number of samples
n_design = 10000

# fetch design distribution parameters theta_lxa corresponding to this temperature
theta_lxa = temp2theta[round(temp, 4)]

# sample from this design distribution.
# the i-th element of designohe_nxlxa is the one-hot-encoded (seq_len x alphabet_size) = (4 x 20)
# representation of the i-the element of designseq_n, which is the length-4 sequence as a str.
t0 = time()
_, designohe_nxlxa, designseq_n = gb1.sample_ohe_from_nuc_distribution(
    theta_lxa, n_design, normalize=True, reject_stop_codon=True
)
print('Sampled {} design sequences for temperature {:.3f} ({} s).\n'.format(
    n_design, temp, int(time() - t0)
))
print('Example design sequences:')
print(designseq_n[: 10])
print()
print('True mean label of this design distribution: {:.3f}.\n'.format(temp2mean[round(temp, 4)]))

# get true labels of design sequences
ydesign_n = np.array([seq2yvar[seq][0] for seq in designseq_n])

# get samples and true labels from training distribution, for reference
_, trainohe_nxlxa, trainseq_n = gb1.sample_ohe_from_nuc_distribution(
    gb1.PNUC_NNK_LXA, n_sample, normalize=False, reject_stop_codon=True
)
print('Sampled {} training sequences from NNK distribution ({} s).\n'.format(n_sample, int(time() - t0)))
print('Example training distribution sequences:')
print(trainseq_n[: 10]) 

# get true labels of train sequences
ytrain_n = np.array([seq2yvar[seq][0] for seq in trainseq_n])

# plot
plt.figure(figsize=(5, 4))
plt.hist(ydesign_n, density=True, alpha=0.5, label=temp)
plt.hist(ytrain_n, density=True, alpha=0.5, label='train')
plt.xlabel('true enrichment score');
plt.ylabel('density')
plt.legend(title='distribution');
# Out:
# Sampled 10000 design sequences for temperature 0.400 (0 s).
#
# Example design sequences:
# ['lvaa', 'fgaa', 'ldaa', 'flsa', 'flaa', 'vsaa', 'lraa', 'lkga', 'lsaa', 'lraa']
#
# True mean label of this design distribution: 0.979.
#
# Sampled 10000 training sequences from NNK distribution (0 s).
#
# Example training distribution sequences:
# ['ases', 'dqvi', 'rkca', 'kgas', 'lgvq', 'vrcn', 'tprg', 'ngtr', 'lhdv', 'nvpv']

# %% [markdown]
# # run temperature selection experiments

# %% [markdown]
# Run these cells

# %%
reload(gb1)

n_trial = 100 # number of trials to run
n_cal = 5000  # number of calibration data points to draw on each trial
target_values = np.arange(0.0, 1.51, 0.05)  # different values of tau, the desired mean label
pp_csv_fname = '../tmp1.csv'        # filename to store PP results (our method)

pp_df, _ = gb1.select_for_mean_with_calibration_data(
    model,
    temp2theta, 
    target_values,
    n_cal=n_cal,
    n_trial=n_trial,
    pp_csv_fname=pp_csv_fname,
    design_samples_fname_prefix='gb1-h10-5k-030123-samples',
    load_design_samples=True
)
# Out:
# Selection quantity is the mean label.
# Range of provided target values: [0.000, 1.500].
#
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2000.npz.
# Done with 100 trials for temperature 0.2000 (1 / 101) (27 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2050.npz.
# Done with 100 trials for temperature 0.2050 (2 / 101) (55 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2100.npz.
# Done with 100 trials for temperature 0.2100 (3 / 101) (83 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2150.npz.
# Done with 100 trials for temperature 0.2150 (4 / 101) (111 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2200.npz.
# Done with 100 trials for temperature 0.2200 (5 / 101) (139 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2250.npz.
# Done with 100 trials for temperature 0.2250 (6 / 101) (168 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2300.npz.
# Done with 100 trials for temperature 0.2300 (7 / 101) (196 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2350.npz.
# Done with 100 trials for temperature 0.2350 (8 / 101) (225 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2400.npz.
# Done with 100 trials for temperature 0.2400 (9 / 101) (253 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2450.npz.
# Done with 100 trials for temperature 0.2450 (10 / 101) (281 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2500.npz.
# Done with 100 trials for temperature 0.2500 (11 / 101) (309 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2550.npz.
# Done with 100 trials for temperature 0.2550 (12 / 101) (337 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2600.npz.
# Done with 100 trials for temperature 0.2600 (13 / 101) (365 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2650.npz.
# Done with 100 trials for temperature 0.2650 (14 / 101) (392 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2700.npz.
# Done with 100 trials for temperature 0.2700 (15 / 101) (420 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2750.npz.
# Done with 100 trials for temperature 0.2750 (16 / 101) (448 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2800.npz.
# Done with 100 trials for temperature 0.2800 (17 / 101) (476 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2850.npz.
# Done with 100 trials for temperature 0.2850 (18 / 101) (504 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2900.npz.
# Done with 100 trials for temperature 0.2900 (19 / 101) (531 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.2950.npz.
# Done with 100 trials for temperature 0.2950 (20 / 101) (559 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.3000.npz.
# Done with 100 trials for temperature 0.3000 (21 / 101) (587 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.3050.npz.
# Done with 100 trials for temperature 0.3050 (22 / 101) (615 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.3100.npz.
# Done with 100 trials for temperature 0.3100 (23 / 101) (643 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.3150.npz.
# Done with 100 trials for temperature 0.3150 (24 / 101) (671 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.3200.npz.
# Done with 100 trials for temperature 0.3200 (25 / 101) (699 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.3250.npz.
# Done with 100 trials for temperature 0.3250 (26 / 101) (727 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.3300.npz.
# Done with 100 trials for temperature 0.3300 (27 / 101) (755 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.3350.npz.
# Done with 100 trials for temperature 0.3350 (28 / 101) (783 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.3400.npz.
# Done with 100 trials for temperature 0.3400 (29 / 101) (812 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.3450.npz.
# Done with 100 trials for temperature 0.3450 (30 / 101) (840 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.3500.npz.
# Done with 100 trials for temperature 0.3500 (31 / 101) (869 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.3550.npz.
# Done with 100 trials for temperature 0.3550 (32 / 101) (898 s).
# Saved PP results to ../tmp1.csv.
# Loaded 1000000 design sequences from /data/wongfanc/gb1-results/gb1-h10-5k-030123-samples-t0.3600.npz.

# %%
# process results for plotting
ppworst_v, pperr_v, ppdisc_v, _ = process_gb1_selection_experiments(
    pp_df, target_values, temperatures, temp2mean, n_trial, imp_or_pp='pp'
)
# Out:
# Processing pp results with 101 temperatures in [0.200, 0.700], 31 target values in [0.00, 1.50], 100 trials, and alpha = 0.1
# Done processing (7 s)

# %%
# plot
fig, axs = plt.subplots(1, 2, figsize=(9, 3), dpi=300)
ax0 = axs[0]
ax1 = axs[1]
fig.subplots_adjust(wspace=0.3)

alpha = 0.1
pp_color = 'yellowgreen'
dark_line_color = 'darkgray'

lw = 2.5
legend_fs = 12
pp_xlim = [-0.05, 1.55]
pp_xticks = np.arange(0, 1.55, 0.3)

q_low = 0.2
q_high = 0.8


# ===== subplot (a) =====
    
ax0.axhline(alpha, linestyle='-', color=dark_line_color, alpha=1, linewidth=2, label=r'$\alpha = {}$'.format(alpha));

ax0.plot(target_values, pperr_v, c=pp_color, linewidth=lw);
ax0.plot(target_values, ppdisc_v, ':', c=pp_color, linewidth=lw);

# dummy to get legend labels
ax0.plot(-1, -1, linestyle='-', color='k', linewidth=lw, label='error rate')
ax0.plot(-1, -1, linestyle=':', color='k', linewidth=lw, label='selection rate')

ax0.set_ylim([-0.05, 1.05])
ax0.set_yticks(np.arange(0, 1.05, 0.2))
ax0.set_xlim(pp_xlim)
ax0.set_xticks(pp_xticks)
ax0.set_ylabel('error/selection rate\n(fraction of trials)');
ax0.set_xlabel(r'desired mean design label ($\tau$)');
ax0.set_title('(a)')
ax0.legend(fontsize=legend_fs, loc='center left', bbox_to_anchor=(-1.27, 0.8))


# ===== subplot (b) =====

ax1.plot([0, 1.5], [0, 1.5], '-', c=dark_line_color, alpha=1, linewidth=2);

ax1.plot(
    target_values, [np.median(worst) if len(worst) else np.nan for worst in ppworst_v],
    c=pp_color, label='prediction-powered (ours)', linewidth=lw,
)
ax1.fill_between(
    target_values, [np.quantile(worst, q_low) if len(worst) else np.nan for worst in ppworst_v],
    [np.quantile(worst, q_high) if len(worst) else np.nan for worst in ppworst_v],
    color=pp_color, alpha=0.5,
)

ax1.set_xlim(pp_xlim)
ax1.set_ylim(pp_xlim)
ax1.set_xticks(pp_xticks)
ax1.set_yticks(pp_xticks)
legend = ax1.legend(fontsize=legend_fs, loc='center right', bbox_to_anchor=(-1.6, 0.2))

ax1.set_title('(b)')
ax1.set_ylabel('achieved mean design label');
ax1.set_xlabel(r'desired mean design label ($\tau$)');
